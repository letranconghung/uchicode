# %%
from typing import Dict, List, Optional, Tuple
import os
import numpy as np
import matplotlib.pyplot as plt
import utils
from scipy import stats

seed = 0
np.random.seed(seed)

from utils import TrainAndTestData, empirical_err
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
Xr, yr = utils.read_sms_spam_data(os.path.join(os.getcwd(), 'data/SMSSpamCollection'))
spamdata = TrainAndTestData(*utils.create_split(Xr, yr, 0.7))

# %%
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import GridSearchCV

Vectorizer = utils.SMS_Vectorizer(spamdata.X_train, d=360)
X = Vectorizer.vectorize(Xr)
y = yr
# vectorized_data = TrainAndTestData(Vectorizer.vectorize(spamdata.X_train), spamdata.y_train, Vectorizer.vectorize(spamdata.X_test), spamdata.y_test)
param_grid = [
    {'max_depth': range(5, 30, 2), 
     'max_leaf_nodes': range(600, 1501, 100),
     'criterion': ["gini", "entropy", "log_loss"],
     "max_features": ["sqrt", "log2", None]
    }
]
base_estimator = DecisionTreeClassifier()
sh = GridSearchCV(base_estimator, param_grid, cv = 5, verbose = 3 ,error_score="raise").fit(X, y)
# Out:
# Fitting 5 folds for each of 1170 candidates, totalling 5850 fits
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=600;, score=0.923 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=600;, score=0.929 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=600;, score=0.908 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=600;, score=0.903 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=600;, score=0.903 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=700;, score=0.901 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=700;, score=0.896 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=700;, score=0.879 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=700;, score=0.896 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=700;, score=0.910 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=800;, score=0.893 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=800;, score=0.915 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=800;, score=0.902 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=800;, score=0.908 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=800;, score=0.897 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=900;, score=0.933 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=900;, score=0.919 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=900;, score=0.891 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=900;, score=0.909 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=900;, score=0.928 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1000;, score=0.911 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1000;, score=0.893 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1000;, score=0.911 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1000;, score=0.902 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1000;, score=0.907 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1100;, score=0.919 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1100;, score=0.888 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1100;, score=0.915 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1100;, score=0.915 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1100;, score=0.918 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1200;, score=0.887 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1200;, score=0.895 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1200;, score=0.897 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1200;, score=0.888 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1200;, score=0.919 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1300;, score=0.902 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1300;, score=0.904 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1300;, score=0.914 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1300;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1300;, score=0.896 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1400;, score=0.907 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1400;, score=0.911 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1400;, score=0.904 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1400;, score=0.898 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1400;, score=0.897 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1500;, score=0.903 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1500;, score=0.908 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1500;, score=0.902 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1500;, score=0.886 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, max_leaf_nodes=1500;, score=0.903 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=600;, score=0.897 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=600;, score=0.903 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=600;, score=0.911 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=600;, score=0.884 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=600;, score=0.884 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=700;, score=0.891 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=700;, score=0.915 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=700;, score=0.886 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=700;, score=0.886 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=700;, score=0.898 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=800;, score=0.894 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=800;, score=0.893 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=800;, score=0.877 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=800;, score=0.910 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=800;, score=0.912 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=900;, score=0.914 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=900;, score=0.888 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=900;, score=0.898 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=900;, score=0.888 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=900;, score=0.883 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1000;, score=0.904 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1000;, score=0.915 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1000;, score=0.901 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1000;, score=0.873 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1000;, score=0.891 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1100;, score=0.894 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1100;, score=0.907 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1100;, score=0.895 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1100;, score=0.889 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1100;, score=0.893 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1200;, score=0.910 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1200;, score=0.917 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1200;, score=0.903 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1200;, score=0.908 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1200;, score=0.918 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1300;, score=0.890 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1300;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1300;, score=0.883 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1300;, score=0.912 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1300;, score=0.909 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1400;, score=0.918 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1400;, score=0.918 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1400;, score=0.890 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1400;, score=0.896 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1400;, score=0.895 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1500;, score=0.907 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1500;, score=0.894 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1500;, score=0.900 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1500;, score=0.897 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, max_leaf_nodes=1500;, score=0.898 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=600;, score=0.957 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=600;, score=0.943 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=600;, score=0.947 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=600;, score=0.943 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=600;, score=0.953 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=700;, score=0.956 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=700;, score=0.943 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=700;, score=0.947 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=700;, score=0.943 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=700;, score=0.952 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=800;, score=0.957 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=800;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=800;, score=0.946 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=800;, score=0.943 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=800;, score=0.956 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes=900;, score=0.957 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=None, max_leaf_nodes
total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=600;, score=0.922 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=600;, score=0.923 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=600;, score=0.921 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=700;, score=0.937 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=700;, score=0.936 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=700;, score=0.918 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=700;, score=0.935 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=700;, score=0.918 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=800;, score=0.946 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=800;, score=0.932 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=800;, score=0.916 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=800;, score=0.914 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=800;, score=0.938 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=900;, score=0.918 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=900;, score=0.928 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=900;, score=0.926 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=900;, score=0.933 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=900;, score=0.949 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1000;, score=0.923 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1000;, score=0.940 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1000;, score=0.939 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1000;, score=0.939 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1000;, score=0.945 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1100;, score=0.924 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1100;, score=0.937 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1100;, score=0.932 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1100;, score=0.919 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1100;, score=0.940 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1200;, score=0.916 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1200;, score=0.929 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1200;, score=0.916 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1200;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1200;, score=0.939 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1300;, score=0.929 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1300;, score=0.938 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1300;, score=0.930 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1300;, score=0.916 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1300;, score=0.933 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1400;, score=0.929 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1400;, score=0.953 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1400;, score=0.942 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1400;, score=0.925 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1400;, score=0.943 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1500;, score=0.938 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1500;, score=0.932 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1500;, score=0.929 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1500;, score=0.931 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, max_leaf_nodes=1500;, score=0.949 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=600;, score=0.945 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=600;, score=0.947 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=600;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=600;, score=0.943 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=600;, score=0.960 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=700;, score=0.951 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=700;, score=0.963 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=700;, score=0.944 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=700;, score=0.945 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=700;, score=0.954 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=800;, score=0.947 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=800;, score=0.958 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=800;, score=0.947 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=800;, score=0.940 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=800;, score=0.960 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=900;, score=0.950 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=900;, score=0.956 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=900;, score=0.945 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=900;, score=0.936 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=900;, score=0.954 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1000;, score=0.951 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1000;, score=0.956 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1000;, score=0.945 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1000;, score=0.943 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1000;, score=0.949 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1100;, score=0.947 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1100;, score=0.956 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1100;, score=0.947 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1100;, score=0.944 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1100;, score=0.961 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1200;, score=0.951 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1200;, score=0.953 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1200;, score=0.949 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1200;, score=0.949 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1200;, score=0.951 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1300;, score=0.949 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1300;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1300;, score=0.946 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1300;, score=0.946 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1300;, score=0.958 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1400;, score=0.949 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1400;, score=0.953 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1400;, score=0.944 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1400;, score=0.947 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1400;, score=0.951 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1500;, score=0.947 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1500;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1500;, score=0.949 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1500;, score=0.936 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, max_leaf_nodes=1500;, score=0.950 total time=   0.1s

# %%
import pandas as pd
df = pd.DataFrame(sh.cv_results_)
df.sort_values(by="rank_test_score")
df.head()

# %%
clf = sh.best_estimator_


vectorized_public_X = Vectorizer.vectorize(spamdata.X_test)
public_y = spamdata.y_test
private_X, private_y = utils.read_sms_spam_data(os.path.join(os.getcwd(), 'data/SMSSpamCollection_test_text'))
vectorized_private_X = Vectorizer.vectorize(private_X)
X = np.concatenate([vectorized_public_X, vectorized_private_X])
pred_y = clf.predict(X)

with open('prediction.csv', 'w') as f:
    f.write('ID,LABEL\n')
    for i, y in enumerate(pred_y):
        f.write(f"{i},{str(y)}\n")
# Out:
# (1833, 360)

# %%
vectorized_public_X = Vectorizer.vectorize(spamdata.X_test)
public_y = spamdata.y_test
private_X, private_y = utils.read_sms_spam_data(os.path.join(os.getcwd(), 'data/SMSSpamCollection_test_text'))
vectorized_private_X = Vectorizer.vectorize(private_X)
X = np.concatenate([vectorized_public_X, vectorized_private_X])

est = DecisionTreeClassifier(max_depth=13, max_leaf_nodes=1000)
est.fit(Vectorizer.vectorize(spamdata.X_train), spamdata.y_train)
pred_y = est.predict(X)

# %%
with open('prediction.csv', 'w') as f:
    f.write('ID,LABEL\n')
    for i, y in enumerate(pred_y):
        f.write(f"{i},{str(y)}\n")
